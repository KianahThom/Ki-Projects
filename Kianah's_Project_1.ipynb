# %% [markdown]
# <a href="https://colab.research.google.com/github/KianahThom/Ki-Projects/blob/main/Kianah's_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
df.drop_duplicates()
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212325     84X717            Icahn Charter School          K-8
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested Mean Score  \
# 0       Common Core Algebra  2017             4          s
# 1        Living Environment  2015            16       77.9
# ...

# %%
df = df.drop_duplicates()
#consolidate info
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212325     84X717            Icahn Charter School          K-8
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested Mean Score  \
# 0       Common Core Algebra  2017             4          s
# 1        Living Environment  2015            16       77.9
# ...

# %%
df.describe()
# Out:
#                 Year   Total Tested
# count  188512.000000  188512.000000
# mean     2015.953775      54.596885
# std         0.803501      97.187287
# min      2015.000000       1.000000
# 25%      2015.000000       7.000000
# 50%      2016.000000      24.000000
# 75%      2017.000000      63.000000
# max      2017.000000    1729.000000

# %%
df.columns
#checking columns
# Out:
# Index(['School DBN', 'School Name', 'School Level', 'Regents Exam', 'Year',
#        'Total Tested', 'Mean Score', 'Number Scoring Below 65',
#        'Percent Scoring Below 65', 'Number Scoring 65 or Above',
#        'Percent Scoring 65 or Above', 'Number Scoring 80 or Above',
#        'Percent Scoring 80 or Above', 'Number Scoring CR',
#        'Percent Scoring CR'],
#       dtype='object')

# %%
#drop cloumns
#Not needed
['Number Scoring CR','Percent Scoring CR']
# Out:
# ['Number Scoring CR', 'Percent Scoring CR']

# %%
drop_cols = ['Number Scoring CR','Percent Scoring CR']

# %%
inplace = True
#set in place

# %%
#Checking for missing values
df.isnull()
# Out:
#         School DBN  School Name  School Level  Regents Exam   Year  \
# 0            False        False         False         False  False
# 1            False        False         False         False  False
# 2            False        False         False         False  False
# 3            False        False         False         False  False
# 4            False        False         False         False  False
# ...            ...          ...           ...           ...    ...
# 212325       False        False         False         False  False
# 212326       False        False         False         False  False
# 212327       False        False         False         False  False
# 212328       False        False         False         False  False
# 212329       False        False         False         False  False
#
#         Total Tested  Mean Score  Number Scoring Below 65  \
# 0              False       False                    False
# ...

# %%
df.notnull()
# Out:
#         School DBN  School Name  School Level  Regents Exam  Year  \
# 0             True         True          True          True  True
# 1             True         True          True          True  True
# 2             True         True          True          True  True
# 3             True         True          True          True  True
# 4             True         True          True          True  True
# ...            ...          ...           ...           ...   ...
# 212325        True         True          True          True  True
# 212326        True         True          True          True  True
# 212327        True         True          True          True  True
# 212328        True         True          True          True  True
# 212329        True         True          True          True  True
#
#         Total Tested  Mean Score  Number Scoring Below 65  \
# 0               True        True                     True
# ...

# %%
df.isnull().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.info()
#getting more details
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 188512 entries, 0 to 212329
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   188512 non-null  object
#  1   School Name                  188512 non-null  object
#  2   School Level                 188512 non-null  object
#  3   Regents Exam                 188502 non-null  object
#  4   Year                         188512 non-null  int64
#  5   Total Tested                 188512 non-null  int64
#  6   Mean Score                   188512 non-null  object
#  7   Number Scoring Below 65      188512 non-null  object
#  8   Percent Scoring Below 65     188512 non-null  object
#  9   Number Scoring 65 or Above   188512 non-null  object
#  10  Percent Scoring 65 or Above  188512 non-null  object
#  11  Number Scoring 80 or Above   188512 non-null  object
# ...

# %%
column_values=df['Regents Exam']

# %%
unique_values=column_values.unique()
unique_values
#what exams are listed and tested
# Out:
# array(['Common Core Algebra', 'Living Environment', 'Common Core English',
#        'Algebra2/Trigonometry', 'Common Core Algebra2',
#        'Common Core Geometry', 'English', 'Geometry',
#        'Global History and Geography', 'Integrated Algebra',
#        'Physical Settings/Chemistry', 'Physical Settings/Earth Science',
#        'U.S. History and Government', 'Physical Settings/Physics', nan],
#       dtype=object)

# %%
RE_value_counts = df['Regents Exam'].value_counts()
print(RE_value_counts)
#checking the counts of each test
# Out:
# Common Core Algebra                26214
# Living Environment                 23544
# U.S. History and Government        19058
# Global History and Geography       18284
# Common Core English                17650
# Physical Settings/Earth Science    14274
# Common Core Geometry               13529
# Physical Settings/Chemistry         9879
# English                             9754
# Integrated Algebra                  9471
# Algebra2/Trigonometry               8653
# Geometry                            6831
# Common Core Algebra2                6680
# Physical Settings/Physics           4681
# Name: Regents Exam, dtype: int64

# %%
df.shape
# Out:
# (188512, 15)

# %%
selected_rows = df[df['School DBN'].isin(['29Q109', '30Q010'])]
print(selected_rows)
# Out:
#        School DBN                     School Name  \
# 15872      29Q109  Jean Nuzzi Intermediate School
# 15873      29Q109  Jean Nuzzi Intermediate School
# 15874      29Q109  Jean Nuzzi Intermediate School
# 15875      29Q109  Jean Nuzzi Intermediate School
# 15876      29Q109  Jean Nuzzi Intermediate School
# ...           ...                             ...
# 201582     30Q010         I.S. 010 Horace Greeley
# 201585     30Q010         I.S. 010 Horace Greeley
# 201587     30Q010         I.S. 010 Horace Greeley
# 201588     30Q010         I.S. 010 Horace Greeley
# 201589     30Q010         I.S. 010 Horace Greeley
#
#                            School Level         Regents Exam  Year  \
# 15872   Junior High-Intermediate-Middle  Common Core Algebra  2015
# 15873   Junior High-Intermediate-Middle  Common Core Algebra  2016
# 15874   Junior High-Intermediate-Middle  Common Core Algebra  2017
# 15875   Junior High-Intermediate-Middle   Living Environment  2015
# ...

# %%
count_s_values = df['Mean Score'].value_counts(dropna=False)['s']
print("Number of rows with 's' in the 'mean score' column:", count_s_values)
# Out:
# Number of rows with 's' in the 'mean score' column: 54981

# %%
# Cleaning out 'count_number_scoring_below_65' with value 's'

count_number_scoring_below_65 = df['Number Scoring Below 65'].value_counts(dropna=False)['s']
print("Number of rows with 's' in the 'Number Scoring Below 65' column:",count_number_scoring_below_65 )
# Out:
# Number of rows with 's' in the 'Number Scoring Below 65' column: 54981

# %%
# Cleaning out 'count_percent_scoring_below_65' with value 's'

count_percent_scoring_below_65 = df['Percent Scoring Below 65'].value_counts(dropna=False)['s']
print("Number of rows with 's' in the 'Percent Scoring Below 65' column:",count_percent_scoring_below_65)
# Out:
# Number of rows with 's' in the 'Percent Scoring Below 65' column: 54981

# %%
# Cleaning out the 's' Value from the below list of columns

columns_with_s_values = ['Mean Score', 'Number Scoring Below 65', 'Percent Scoring Below 65',
                         'Number Scoring 65 or Above', 'Percent Scoring 65 or Above',
                         'Number Scoring 80 or Above', 'Percent Scoring 80 or Above']
